# %%
from splinter import Browser
from bs4 import BeautifulSoup as bs
import requests
from selenium import webdriver


import glob
import pandas as pd
from zipfile import ZipFile


#executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
#browser = Browser('chrome', **executable_path, headless=False)

# %%
    # @NOTE: Replace the path with your actual path to the chromedriver
    # make sure to change browsers downloads settings to destination of your preference
executable_path = {"executable_path": "/usr/local/bin/chromedriver"}
browser = Browser("chrome", **executable_path, headless=False)



url = "https://s3.amazonaws.com/tripdata/index.html"
browser.visit(url)

links = browser.find_by_tag('a')


for i in links:
    
    #ALL SPLINTER ELEMENTS, NOT ABLE TO USE CONDITIONALS
    #z = str(i)
    #print(z)
    #if z.startswith('2020'):
    i.click()

# %%
files = glob.glob('/Users/claytonhribar/Documents/Citi-bike-project/Data/*.zip')

# %%
table = []



for i in files:
    

    zf = ZipFile(i)
    
    name = zf.namelist()[0]
    
    print(name)

    df = pd.read_csv(zf.open(name))
    
    #df['starttime'] = pd.to_datetime(df.starttime)
    
    #df = df.set_index(['starttime'])
    
    table.append(df)

# %%
bike_df = pd.concat(table)

# %%
bike_df.head()

# %%
#bike_df.to_csv('../../data/all_citi_bike_data.csv', index=False)

# %%
len(bike_df.index)
